# %%
import pandas as pd
import numpy as np

# %%
pem = pd.read_pickle("../data/pulled/pem.pkl")

# %%
pem.head()
# Out:
#    PLAYER_ID   PLAYER_NAME  GP  W  L  W_PCT  MIN  E_OFF_RATING  E_DEF_RATING  \
# 0       1578    Shea Seals   4  3  1  0.750  2.0          83.0          96.2
# 1       1522   Keith Booth   6  4  2  0.667  2.8          92.2         102.3
# 2       1526  James Cotton   9  7  2  0.778  3.8          83.0         119.2
# 3       1472  Tom Chambers   1  0  1  0.000  9.7          80.9          98.7
# 4       1575   Derek Grimm   9  2  7  0.222  3.7         108.2         127.0
#
#    E_NET_RATING  ...  E_DEF_RATING_RANK  E_NET_RATING_RANK  E_AST_RATIO_RANK  \
# 0         -13.1  ...                 41                403               427
# 1         -10.0  ...                237                375               355
# 2         -36.2  ...                437                438               427
# 3         -17.8  ...                105                423               427
# 4         -18.8  ...                441                427               427
#
# ...

# %%
team_roster=pd.read_pickle("../data/pulled/team_roster.pkl")

# %%
team_roster.sort_values(by=['PLAYER', 'SEASON'])
# Out:
#           TeamID SEASON LeagueID              PLAYER         PLAYER_SLUG NUM  \
# 58    1610612742   1997       00          A.C. Green            ac-green  45
# 407   1610612742   1998       00          A.C. Green            ac-green  45
# 813   1610612747   1999       00          A.C. Green            ac-green  45
# 1175  1610612748   2000       00          A.C. Green            ac-green  45
# 1078  1610612741   2000       00         A.J. Guyton           aj-guyton  11
# ...          ...    ...      ...                 ...                 ...  ..
# 3902  1610612739   2007       00  Zydrunas Ilgauskas  zydrunas-ilgauskas  11
# 4337  1610612739   2008       00  Zydrunas Ilgauskas  zydrunas-ilgauskas  11
# 4767  1610612739   2009       00  Zydrunas Ilgauskas  zydrunas-ilgauskas  11
# 5333  1610612748   2010       00  Zydrunas Ilgauskas  zydrunas-ilgauskas  11
# 9355  1610612740   2019       00      Zylan Cheatham      zylan-cheatham  45
#
# ...

# %%
team_roster.merge(right=team_roster, how='left', left_on=team_roster['SEASON'].apply(int), right_on=team_roster['SEASON'].apply(int) + 1)
# Out:
#          key_0    TeamID_x SEASON_x LeagueID_x           PLAYER_x  \
# 0         1997  1610612737     1997         00      Greg Anderson
# 1         1997  1610612737     1997         00     Anthony Miller
# 2         1997  1610612737     1997         00  Eldridge Recasner
# 3         1997  1610612737     1997         00     Chris Crawford
# 4         1997  1610612737     1997         00       Steven Smith
# ...        ...         ...      ...        ...                ...
# 4027948   2019  1610612766     2019         00        Cody Zeller
# 4027949   2019  1610612766     2019         00        Cody Zeller
# 4027950   2019  1610612766     2019         00        Cody Zeller
# 4027951   2019  1610612766     2019         00        Cody Zeller
# 4027952   2019  1610612766     2019         00        Cody Zeller
#
#              PLAYER_SLUG_x NUM_x POSITION_x HEIGHT_x WEIGHT_x  ... NUM_y  \
# 0            greg-anderson     0        C-F     6-10      250  ...   NaN
# ...
